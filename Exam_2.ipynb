# %% [markdown]
# <a href="https://colab.research.google.com/github/pingping-0606/Python_dataviz2024/blob/main/Exam_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exam_2

# %% [markdown]
# ให้สืบหาฆาตรกร ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL City โดยเริ่มจากการตรวจสอบ ข้อมูลคดี (crime_scene_report.csv)
#
# หมายเหตุ
# person.csv ข้อมูลประชากร
# interview.csv ข้อมูลการสอบสวน
# income.csv ข้อมูลรายได้
# get_fit_now_member.csv ข้อมูลสมาชิก ฟิตเนส Get Fit Now
# get_fit_now_check_in.csv ข้อมูลการเข้าใช้ ฟิตเนส Get Fit Now
# facebook_event_checkin.csv ข้อมูลการเช็คอิน Facebook
# driver_license.csv ข้อมูลใบขับขี่
# crime_scene_report.csv ข้อมูลคดี

# %%
import numpy as np
import pandas as pd

# %%
crime_scene_report = pd.read_csv('/content/crime_scene_report.csv')

# %%
person = pd.read_csv('/content/person.csv')

# %%
interview = pd.read_csv('/content/interview.csv')

# %%
income = pd.read_csv('/content/income.csv')

# %%
get_fit_now_check_in = pd.read_csv('/content/get_fit_now_check_in.csv')

# %%
get_fit_now_member = pd.read_csv('/content/get_fit_now_member.csv')

# %%
facebook_event_checkin = pd.read_csv('/content/facebook_event_checkin.csv')

# %%
driver_license = pd.read_csv('/content/drivers_license.csv')

# %%
crime_scene_report
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %% [markdown]
# กรองข้อมูลที่เป็นคดีฆาตกรรม ในวันที่ 15 มกราคม 2018 ที่เมือง SQL city

# %%
crime_scene_report[crime_scene_report.type == 'murder']
# Out:
#           date    type                                        description  \
# 1     20180115  murder                  Life? Dont talk to me about life.
# 2     20180115  murder  Mama, I killed a man, put a gun against his he...
# 3     20180215  murder                         REDACTED REDACTED REDACTED
# 4     20180215  murder  Someone killed the guard! He took an arrow to ...
# 33    20170107  murder  ‘It proves nothing of the sort!’ said Alice. ‘...
# ...        ...     ...                                                ...
# 1214  20180427  murder              ‘Only a thimble,’ said Alice sadly.\n
# 1215  20180428  murder  wag my tail when I’m angry. Therefore I’m mad.’\n
# 1220  20180429  murder  (she was obliged to say ‘creatures,’ you see, ...
# 1221  20180430  murder               ‘But what am I to do?’ said Alice.\n
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#                 city
# 1             Albany
# 2               Reno
# ...

# %%
crime_scene_report[crime_scene_report.type == 'murder'].shape[0]
# Out:
# 148

# %%
crime_2018_01_15 = crime_scene_report[crime_scene_report['date'] == 20180115]
crime_2018_01_15
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 5     20180115    theft                    Big Bully stole my lunch money!
# 6     20180115    fraud  Lorem ipsum dolor sit amet, consectetur adipis...
# 11    20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 12    20180115  assault                                   Report Not Found
# 972   20180115    arson  like a mouse, you know. But do cats eat bats, ...
# 973   20180115  bribery  Here the other guinea-pig cheered, and was sup...
# 974   20180115    fraud  The Dormouse slowly opened his eyes. ‘I wasn’t...
# 975   20180115    fraud  King put on his spectacles and looked anxiousl...
# ...

# %%
crime_2018_01_15 = crime_scene_report[crime_scene_report['date'] == 20180115].shape[0]
crime_2018_01_15
# Out:
# 12

# %%
crime_scene_report[crime_scene_report.city == 'SQL City']
# Out:
#           date     type                                        description  \
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# 7     20170712    theft  A lone hunter stalks the night, firing arrows ...
# 8     20170820    arson  Wield the Hammer of Sol with honor, Titan, it ...
# 9     20171110  robbery  The Gjallarhorn shoulder-mounted rocket system...
# 10    20180103  bribery  Apparently, Cayde thought it necessary to expo...
# 11    20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 12    20180115  assault                                   Report Not Found
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#           city
# 3     SQL City
# 4     SQL City
# 7     SQL City
# 8     SQL City
# 9     SQL City
# 10    SQL City
# 11    SQL City
# 12    SQL City
# 1227  SQL City

# %%
crime_scene_report[crime_scene_report.city == 'SQL City'].shape[0]
# Out:
# 9

# %% [markdown]
# เหตูการณ์ที่เกิดขึ้นในวันที่ 15 มกราคม 2018

# %%
crime_scene_report[(crime_scene_report['date']==20180115) & (crime_scene_report['type']=='murder') & (crime_scene_report['city']=='SQL City')]
# Out:
#           date    type                                        description  \
# 1227  20180115  murder  Security footage shows that there were 2 witne...
#
#           city
# 1227  SQL City

# %% [markdown]
# คำอธิบายเหตุฆาตกรรมที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง SQL คือ ภาพจากกล้องวงจรปิดพบว่ามีพยาน 2 คน พยานคนแรกอาศัยอยู่ที่บ้านหลังสุดท้ายบน Northwestern Dr พยานคนที่สองชื่อแอนนาเบล อาศัยอยู่ที่ไหนสักแห่งบน Franklin Ave

# %% [markdown]
# ต่อมาจะทำการหาข้อมูลอื่นๆของ พยานคนแรกและคนที่สอง

# %%
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %% [markdown]
# หาว่ามีใครบ้างที่อาศัยอยู่บน Northwestern Dr

# %%
person[person.address_street_name == 'Northwestern Dr']
# Out:
#          id                  name  license_id  address_number  \
# 2     10010             Muoi Cary      385336             741
# 282   12711        Norman Apolito      667757             599
# 499   14887        Morty Schapiro      118009            4919
# 528   15171          Weldon Penso      336999             311
# 811   17729        Lasonya Wildey      439686            3824
# 904   18376              Josh Shi      653712            1091
# 1021  19420           Cody Schiel      890431            3524
# 1338  22239         Dusty Sigafus      710517            1125
# 1426  23044          Val Portlock      924989            3143
# 1522  23960  Kristopher Lagerberg      658777            1392
# 1686  25615         Olevia Morena      388477             812
# 1812  26758      Angelena Billman      942074             629
# 1981  28360        Rashad Cascone      924517            3212
# 2131  29608       Willetta Lurvey      800568            1028
# ...

# %% [markdown]
# เรียง address_number จากน้อยไปมาก เพื่อหาว่าบ้านหลังไหนคือหลังสุดท้าย

# %%
person[person.address_street_name == 'Northwestern Dr'].sort_values('address_number')
# Out:
#          id                  name  license_id  address_number  \
# 8888  89906       Kinsey Erickson      510019             309
# 528   15171          Weldon Penso      336999             311
# 3316  40336       Fredia Billeter      251082             404
# 8369  85280             Donn Duin      569122             540
# 282   12711        Norman Apolito      667757             599
# 7296  75484          Del Tacderen      447887             607
# 1812  26758      Angelena Billman      942074             629
# 3237  39688            Abe Roeker      537445             689
# 2     10010             Muoi Cary      385336             741
# 3368  40760          Renata Faver      976650             745
# 1686  25615         Olevia Morena      388477             812
# 9991  99826          Ivy Kazarian      994470             892
# 3795  44542        Ivory Mcgrevey      873842             897
# 5024  55130        Shiloh Huntoon      472118             951
# ...

# %% [markdown]
# พยานคนแรกคือ Morty Schapiro เลขประจำตัวคือ 14887 มีเลขที่ใบขับขี่คือ 118009 อยู่บ้านเลขที่ 4919  ssn คือ 111564949

# %%
person[person.address_street_name == 'Franklin Ave']
# Out:
#          id                 name  license_id  address_number  \
# 235   12207       Wilmer Wolever      509484             139
# 665   16371       Annabel Miller      490173             103
# 807   17683        Johnnie Schee      968887            1277
# 936   18651        Carleen Etoll      356746              22
# 1377  22636       Zachary Ybarbo      768359             785
# 1608  24737           Gema Nantz      273410            3968
# 2236  30654      Clarita Rickels      418084            2254
# 2427  32264       Shelby Dezeeuw      735415            1391
# 2584  33793         Amado Mattan      161915              99
# 2661  34592    Cordell Lindamood      592762            3657
# 2864  36328         Domenic Laun      971080            3809
# 2877  36400         Noe Pancoast      895755            3443
# 3009  37616     Katelyn Schwerin      430143             332
# 4086  46827         Bev Billiter      643591            2316
# ...

# %%
person[(person.name == 'Annabel Miller') & (person.address_street_name == 'Franklin Ave')]
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %% [markdown]
# พยานคนที่สองคือ Annabel Miller เลขประจำตัวคือ 16371 มีเลขที่ใบขับขี่คือ 490173 อยู่บ้านเลขที่ 103  ssn คือ 318771143

# %%
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
interview[(interview.person_id == 14887) | (interview.person_id == 16371)]
# Out:
#       person_id                                         transcript
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# ข้อมูลการสอบสวนของพยานคนแรกคือ ฉันได้ยินเสียงปืนดังขึ้นและเห็นชายคนหนึ่งวิ่งออกมา เขาถือกระเป๋า "Get Fit Now Gym" หมายเลขสมาชิกบนกระเป๋าเริ่มต้นด้วย "48Z" เฉพาะสมาชิกโกลด์เท่านั้นที่มีกระเป๋าแบบนั้น ชายคนนั้นขึ้นรถที่มีป้ายทะเบียน "H42W"

# %% [markdown]
# ข้อมูลการสอบสวนของพยานคนที่สองคือ ฉันได้เห็นการฆาตกรรมเกิดขึ้น และฉันจำฆาตกรได้จากโรงยิมของฉัน ขณะที่ฉันกำลังออกกำลังกายเมื่อสัปดาห์ที่แล้วในวันที่ 9 มกราคม

# %% [markdown]
# ต่อมาจะทำการหาว่าใครที่เป็นสมาชิกโกลด์ของยิมนี้ ที่มีหมายเลขสมาชิกบนกระเป๋าเริ่มต้นด้วย "48Z" และป้ายทะเบียนรถเป็น "H42W"

# %%
get_fit_now_member
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
get_fit_now_member[(get_fit_now_member.membership_status == 'gold') & (get_fit_now_member.id.str[:3] == '48Z')]
# Out:
#         id  person_id           name  membership_start_date membership_status
# 181  48Z7A      28819   Joe Germuska               20160305              gold
# 182  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# จากคำให้การของพยานคนแรกมีผู้ต้องสงสัยสองคนคือ Joe Germuska และ Jeremy Bowers

# %%
driver_license
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
driver_license[driver_license.plate_number.str[:4] == 'H42W']
# Out:
#          id  age  height eye_color hair_color  gender plate_number car_make  \
# 915  183779   21      65      blue     blonde  female       H42W0X   Toyota
#
#     car_model
# 915     Prius

# %% [markdown]
# จากคำให้การของพยานคนแรกว่าเห็นฆาตกรขึ้นรถทะเบียน H42W ซึ่งเจ้าของรถเป็นผู้หญิง อายุ 21 ปี ผมสีบลอนด์ ตาสีฟ้า

# %%
get_fit_now_check_in
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
get_fit_now_check_in[(get_fit_now_check_in.check_in_date == 20180109) & (get_fit_now_check_in.membership_id.str[:3] == '48Z')]
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700

# %% [markdown]
# จากคำให้การของพยานคนที่สองว่าฆาตกรเป็นผู้ที่เข้าใช้บริการยิมในวันที่ 9 มกราคม 2018 มีผู้ต้องสงสัยตรงกับพยานคนแรกคือ Joe Germuska และ Jeremy Bowers

# %%
person[(person.name == 'Joe Germuska') | (person.name == 'Jeremy Bowers')]
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 2037  28819   Joe Germuska      173289             111                Fisk Rd
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 2037  138909730
# 6327  871539279

# %%
facebook_event_checkin
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
facebook_event_checkin[facebook_event_checkin.person_id == 28819]
# Out:
# Empty DataFrame
# Columns: [person_id, event_id, event_name, date]
# Index: []

# %% [markdown]
# Joe Germuska ไม่มีข้อมูล facebook_event_checkin

# %%
facebook_event_checkin[facebook_event_checkin.person_id == 67318]
# Out:
#        person_id  event_id              event_name      date
# 20009      67318      4719  The Funky Grooves Tour  20180115
# 20010      67318      1143    SQL Symphony Concert  20171206

# %% [markdown]
# Jeremy Bowers มีข้อมูลการค้นหาคือ ทัวร์ Funky Grooves ในวันที่ 15 มกราคม 2018 และ คอนเสิร์ต SQL Symphony ในวันที่ 6 ธันวาคม 2017

# %%
interview[interview.person_id == 67318]
# Out:
#       person_id                                         transcript
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# คำให้การของ Jeremy Bowers คือ ฉันถูกจ้างโดยผู้หญิงคนหนึ่งที่มีเงินมากมาย ฉันไม่ทราบชื่อของเธอ แต่ฉันรู้ว่าเธอสูงประมาณ 5 ฟุต 5 นิ้ว (65 นิ้ว) หรือ 5 ฟุต 7 นิ้ว (67 นิ้ว) เธอมีผมสีแดงและขับรถ Tesla Model S ฉันรู้ว่าเธอไปชมคอนเสิร์ต SQL Symphony 3 ครั้งในเดือนธันวาคม 2017

# %% [markdown]
# สรุปได้ว่าฆาตกรคือ Jeremy Bowers เป็นผู้ลงมือสังหาร โดยมีผู้จ้างอีกทีคาดว่าเขาน่าจะได้เจอกับเธอตอนที่ไปชมคอนเสิร์ต SQL Symphonyในเดือนธันวาคม ปี 2017 เพราะประวัติการค้นหา facebook ของฆาตกร มีการค้นหา คอนเสิร์ต SQL Symphony ในวันที่ 6 ธันวาคม 2017 ซึ่งก็สามารถเป็นหลักฐานได้ว่าฆาตกรได้เจอกับคนจ้างวานจริงๆ
